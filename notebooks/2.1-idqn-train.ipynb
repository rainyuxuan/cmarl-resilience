# %% [markdown]
# # Indepedent Deep Q-Network (IDQN) Training

# %%
from cmarl.utils import today

# %%
env_name = 'adversarial_pursuit'
model_name = 'idqn'

task_name = f'{model_name}-{env_name}-2024-12-09'

# %% [markdown]
# ## Train Model

# %% [markdown]
# ## Visualize Results

# %%
from cmarl.utils import load_data

num_episodes = 160
train_scores = load_data(f'{task_name}-train_scores')
test_scores = load_data(f'{task_name}-test_scores')

# %% [markdown]
# ### Plot training and test scores

# %%
from cmarl.utils.viz import plot_rewards_over_episodes

plot_rewards_over_episodes(train_scores, title='IDQN Train Scores')

plot_rewards_over_episodes(test_scores, title='IDQN Test Scores')
