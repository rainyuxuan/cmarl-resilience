# %% [markdown]
# # Value Decomposition Network: Random Agent Experiments

# %%
from cmarl.utils.data import save_dict, load_dict

# %% [markdown]
# ## Run Experiment

# %%
env_name = 'adversarial_pursuit'     # 'adversarial_pursuit', 'tiger_deer'
model_name = 'VDN'
date = '2024-12-12'
suffix = ''

task_name = f'{model_name}-{env_name}-{date}' + (f'-{suffix}' if suffix else '')

# %% [markdown]
# ## Visualize Results

# %%
rate_avg_scores = load_dict(f'{task_name}-rate_avg_scores')
rate_scores = load_dict(f'{task_name}-rate_scores')

# %% [markdown]
# ### Plot Average Scores Over Random Rates

# %%
from cmarl.utils.viz import plot_avg_scores_over_random_rates

plot_avg_scores_over_random_rates(rate_avg_scores, title=f'{model_name.upper()}: Average Scores over Random Rates in {env_name}')

# %%
from cmarl.utils.viz import plot_scores_over_random_rates_with_variance

plot_scores_over_random_rates_with_variance(rate_scores, title=f'{model_name.upper()}: Score Means & Std over Random Rates in {env_name}')

# %%
from cmarl.utils.viz import plot_variance_over_random_rates

plot_variance_over_random_rates(rate_scores, title=f'{model_name.upper()}: Score Standard Deviation over Random Rates in {env_name}')

# %%
from cmarl.utils.viz import plot_stacked_rewards_over_episodes
