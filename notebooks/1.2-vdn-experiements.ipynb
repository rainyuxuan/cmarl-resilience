# %% [markdown]
# # Value Decomposition Network: Random Agent Experiments

# %%
from cmarl.utils import today
from cmarl.utils.data import save_dict, load_dict

# %% [markdown]
# ## Run Experiment

# %%
env_name = 'adversarial_pursuit'
model_name = 'vdn'

task_name = f'{model_name}-{env_name}-{today}'

# %% [markdown]
# ## Visualize Results

# %%
rate_avg_scores = load_dict(f'{task_name}-rate_avg_scores')
rate_scores = load_dict(f'{task_name}-rate_scores')

# %% [markdown]
# ### Plot Average Scores Over Random Rates

# %%
from cmarl.utils.viz import plot_avg_scores_over_random_rates

plot_avg_scores_over_random_rates(rate_avg_scores, title='VDN: Scores over Random Rates')

# %%
from cmarl.utils.viz import plot_scores_over_random_rates_with_variance

plot_scores_over_random_rates_with_variance(rate_scores, title='VDN: Scores over Random Rates')
